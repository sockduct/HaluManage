# %% [markdown]
# # HaluManage
#
# CIS 583 Term Project - Hallucination Detection and Mitigation

# %%
import sys

sys.path.insert(0, '/notebooks/halumanage/scripts/osiris')
import osiris_hallucination_detector as detector

# %%
# dataset = '/datasets/frames-with-ma-context-10p/frames_with_ma_context_28-10p.json'
dataset = './data/frames_with_ma_context_28.json'
outfile = './data/results-oracle-FlashLite-FlashLite-final-trunc-processed.json'

# %%
detector.run_detector(dataset, outfile, visualize=True, inline=True)
# Out:
# Loading: judgmentlabs/Qwen2.5-Osiris-7B-Instruct
# Device: GPU
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Default tokenizer max length: 4096
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.09G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.33G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Adjusted tokenizer max length: 32768
# Model loaded successfully
#
# Loading: ./data/frames_with_ma_context_28.json
#
# ================================================================================
# DATASET SUMMARY
# ================================================================================
#
# Total Samples: 819
#
# Fields Present: ['Answer', 'Context', 'GraderDecision', 'GraderExplanation', 'Index', 'ModelAnswer', 'Prompt', 'ReasoningTypes']
#
# Field Completeness:
# ================================================================================
#
# Valid samples: 819
# Detecting: 100%|██████████| 819/819 [33:31<00:00,  2.46s/sample]
# Detection complete
#
# ================================================================================
# EVALUATION METRICS
# ================================================================================
#
# Total Samples:              819
# Hallucinations Detected:    48 (5.9%)
# Samples with Context:       819 (100.0%)
# High Confidence Detections: 819 (100.0%)
#
# Base Detection Performance (vs Ground Truth):
#   Accuracy:  0.866
#   Precision: 0.917
#   Recall:    0.293
#   F1-Score:  0.444
#
# Base Confusion Matrix:
#   TP=44   FP=4
#   FN=106  TN=665
# --------------------------------------------------------------------------------
#
#
# Alt Detection Performance (vs Ground Truth):
#   Accuracy:  0.866
#   Precision: 0.863
#   Recall:    0.994
#   F1-Score:  0.924
#
# Alt Confusion Matrix:
#   TP=665  FP=106
#   FN=4    TN=44
# ================================================================================
#
# Saved: ./data/results-oracle-FlashLite-FlashLite-final-trunc-processed.json
# Generated 3 visualizations
#
# ================================================================================
# DETECTION COMPLETE
# ================================================================================
#
# Results saved to: ./data/results-oracle-FlashLite-FlashLite-final-trunc-processed.json
# Visualizations: 3 files
# Hallucinations detected: 48
